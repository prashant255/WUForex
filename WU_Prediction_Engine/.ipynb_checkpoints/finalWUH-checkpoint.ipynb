# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import sklearn

# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
client.list_database_names()
db = client["LP-database"]
LP_predict_collection = db["lp_prediction"]
LP_predict_collection.remove({})
# Out:
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
# {'n': 70, 'ok': 1.0}

# %%
contracts  = 10000.0
count=1
def calc_profit(row):
    if row['won']:
        return abs(row['return'])*contracts
    else:
        return -abs(row['return'])*contracts

def predictBestLP(df, lpid):
    global count
    df['return'] = df['Ohlc'] - df['Ohlc'].shift(1)
    return_range = df['return'].max() - df['return'].min()
    df['return'] = df['return'] / return_range
    df['label'] = df['return'].shift(-1)
    df['label'] = df['label'].apply(lambda x: 1 if x>0.0 else 0)
    df['return'].fillna((df['return'].mean()), inplace = True) 
    n_features = 60 # number of features
    train_x = np.array([]).reshape([-1,n_features])
    train_y = np.array([]).reshape([-1,1])
    for index, row in df.iterrows():
        i = df.index.get_loc(index)
        if i<n_features:
            continue
    
        _x = np.array(df[i-n_features+1:i+1]['return']).T.reshape([1, -1])
        _y = df.iloc[i]['label']
        train_x = np.vstack((train_x, _x))
        train_y = np.vstack((train_y, _y))
    train_y = train_y.reshape([-1])
    print(train_x.shape)
    print(train_y.shape)
    print('%% of Class0 : %f' % (np.count_nonzero(train_y == 0)/float(len(train_y))))
    print('%% of Class1 : %f' % (np.count_nonzero(train_y == 1)/float(len(train_y))))
    from sklearn.neighbors import KNeighborsClassifier 
    knn = KNeighborsClassifier(n_neighbors=3) 
    knn.fit(train_x,train_y) 
    train_len = int(len(train_x)*0.80)
    accuracy = knn.score(train_x[train_len:], train_y[train_len:])
    print('Training Accuracy: %f' % accuracy)
    test_len = int(len(train_x)*0.20)
    accuracy = knn.score(train_x[:test_len], train_y[:test_len])
    print('Testing Accuracy: %f' % accuracy)
    pred = knn.predict(train_x[train_len:])
    df_trade = pd.DataFrame(train_x[train_len:,-1], columns=['return'])
    df_trade['label']  = train_y[train_len:]
    df_trade['pred']   = pred
    df_trade['won']    = df_trade['label'] == df_trade['pred']
    df_trade['return'] = df_trade['return'].shift(-1) * return_range
    df_trade.drop(df_trade.index[len(df_trade)-1], inplace=True)
    df_trade['pnl'] = df_trade.apply(lambda row: calc_profit(row), axis=1)
    df_trade['equity'] = df_trade['pnl'].cumsum()

    display(df_trade.tail())
    df_trade.plot(y='equity', figsize=(10,4), title='Backtest with $10000 initial capital')
    plt.xlabel('Trades')
    plt.ylabel('Equity (USD)')
    for r in df_trade.iterrows():
        if r[1]['won']:
            plt.axvline(x=r[0], linewidth=0.5, alpha=0.8, color='g')
        else:
            plt.axvline(x=r[0], linewidth=0.5, alpha=0.8, color='r')
    n_win_trades = float(df_trade[df_trade['pnl']>0.0]['pnl'].count())
    n_los_trades = float(df_trade[df_trade['pnl']<0.0]['pnl'].count())
    print("Net Profit            : $%.2f" % df_trade.tail(1)['equity'])
    netProfit=int(df_trade.tail(1)['equity'])
    print("Number Winning Trades : %d" % n_win_trades)
    print("Number Losing Trades  : %d" % n_los_trades)
    print("Percent Profitable    : %.2f%%" % (100*n_win_trades/(n_win_trades + n_los_trades)))
    print("Avg Win Trade         : $%.3f" % df_trade[df_trade['pnl']>0.0]['pnl'].mean())
    print("Avg Loss Trade         : $%.3f" % df_trade[df_trade['pnl']<0.0]['pnl'].mean())
    print("Largest Win Trade     : $%.3f" % df_trade[df_trade['pnl']>0.0]['pnl'].max())
    print("Largest Loss Trade     : $%.3f" % df_trade[df_trade['pnl']<0.0]['pnl'].min())
    print("Profit Factor         : %.2f" % abs(df_trade[df_trade['pnl']>0.0]['pnl'].sum()/df_trade[df_trade['pnl']<0.0]['pnl'].sum()))
    LP_predict_collection.insert_one({"currencyPair":df['currencyPair'].iloc[0],"LP_id":lpid,"PercentProfitable":(100*n_win_trades/(n_win_trades + n_los_trades)),"ProfitFactor":abs(df_trade[df_trade['pnl']>0.0]['pnl'].sum()/df_trade[df_trade['pnl']<0.0]['pnl'].sum()),"NetProfit":netProfit})
    df_trade['pnl'].hist(bins=20)
    count=count+1

# %%
def performPred(df):
    LP1=df.loc[df['LP_id'] == 1]  
    LP2=df.loc[df['LP_id'] == 2]
    LP3=df.loc[df['LP_id'] == 3]  
    LP4=df.loc[df['LP_id'] == 4]
    LP5=df.loc[df['LP_id'] == 5]  
    LP6=df.loc[df['LP_id'] == 6]
    LP7=df.loc[df['LP_id'] == 7]
    predictBestLP(LP1, 1)
    predictBestLP(LP2, 2)
    predictBestLP(LP3, 3)
    predictBestLP(LP4, 4)
    predictBestLP(LP5, 5)
    predictBestLP(LP6, 6)
    predictBestLP(LP7, 7)
    
    recommendation = db["lp_pred_count"]
    x=LP_predict_collection.find_one({'currencyPair':df['currencyPair'].iloc[0]},sort=[("ProfitFactor", -1)])['LP_id']
    counter=recommendation.find_one({"currencyPair":df['currencyPair'].iloc[0],"LPid":x})['count']
    myquery= { "LPid": x,'currencyPair':df['currencyPair'].iloc[0] }
    newvalues = { "$set": { "count": counter+1 } }
    recommendation.update_one(myquery, newvalues)

# %%
collection = db["cp1"]
pipeline = [
    {"$unwind":{'path': '$LP', 'preserveNullAndEmptyArrays': True}},
    {"$unwind":{'path': '$LP.details', 'preserveNullAndEmptyArrays': True}},
    {'$project':{
      'id':'$id','LP_id':"$LP.id",'currencyPair':'$currencyPair','timestamp':"$LP.details.timestamp",'open':"$LP.details.open",'close':"$LP.details.close",'high':"$LP.details.high",
        'low':"$LP.details.low"
    }}
]

df = pd.DataFrame() 

query_result = collection.aggregate(pipeline)
query_result = list(query_result)
df = pd.io.json.json_normalize(query_result)
df.drop('_id', axis=1, inplace=True)
# Out:
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   from ipykernel import kernelapp as app

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60936 entries, 0 to 60935
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LP_id         60936 non-null  int64
#  1   currencyPair  60936 non-null  object
#  2   timestamp     60936 non-null  float64
#  3   open          60936 non-null  float64
#  4   close         60936 non-null  float64
#  5   high          60936 non-null  float64
#  6   low           60936 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.3+ MB

# %%
df = df.dropna(axis = 0, how ='any')

# %%
df['Ohlc'] =(df['low'] + df['high'] + df['open'] + df['close'])/4

# %%
#for all currency pair

EURGBP=df.loc[df['currencyPair'] == "EURGBP"]
USDJPY=df.loc[df['currencyPair'] == "USDJPY"]
USDCHF=df.loc[df['currencyPair'] == "USDCHF"]
EURUSD=df.loc[df['currencyPair'] == "EURUSD"]
EURAUD=df.loc[df['currencyPair'] == "EURAUD"]
GBPAUD=df.loc[df['currencyPair'] == "GBPAUD"]
GBPCAD=df.loc[df['currencyPair'] == "GBPCAD"]
NZDJPY=df.loc[df['currencyPair'] == "NZDJPY"]
NZDUSD=df.loc[df['currencyPair'] == "NZDUSD"]
EURJPY=df.loc[df['currencyPair'] == "EURJPY"]
performPred(EURGBP)
performPred(USDJPY)
performPred(USDCHF)
performPred(EURUSD)
performPred(EURAUD)
performPred(GBPAUD)
performPred(GBPCAD)
performPred(NZDJPY)
performPred(NZDUSD)
performPred(EURJPY)
# Out:
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.518152
# % of Class1 : 0.481848
# Training Accuracy: 0.785714
# Testing Accuracy: 0.767956
#        return  label  pred    won    pnl   equity
# 176 -0.000350    0.0   0.0   True  3.500  518.175
# 177 -0.000530    0.0   0.0   True  5.300  523.475
# 178 -0.000668    0.0   0.0   True  6.675  530.150
# 179  0.000133    1.0   0.0  False -1.325  528.825
# 180  0.000347    1.0   1.0   True  3.475  532.300
# Net Profit            : $532.30
# Number Winning Trades : 143
# Number Losing Trades  : 38
# Percent Profitable    : 79.01%
# Avg Win Trade         : $4.721
# Avg Loss Trade         : $-3.757
# Largest Win Trade     : $30.025
# Largest Loss Trade     : $-17.350
# Profit Factor         : 4.73
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.519252
# % of Class1 : 0.480748
# Training Accuracy: 0.774725
# Testing Accuracy: 0.729282
#        return  label  pred    won    pnl   equity
# 176 -0.000345    0.0   1.0  False -3.450  532.550
# 177 -0.000532    0.0   0.0   True  5.325  537.875
# 178 -0.000660    0.0   0.0   True  6.600  544.475
# 179  0.000105    1.0   1.0   True  1.050  545.525
# 180  0.000352    1.0   1.0   True  3.525  549.050
# Net Profit            : $549.05
# Number Winning Trades : 141
# Number Losing Trades  : 40
# Percent Profitable    : 77.90%
# Avg Win Trade         : $4.742
# Avg Loss Trade         : $-2.991
# Largest Win Trade     : $30.325
# Largest Loss Trade     : $-14.000
# Profit Factor         : 5.59
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.517052
# % of Class1 : 0.482948
# Training Accuracy: 0.774725
# Testing Accuracy: 0.734807
#        return  label  pred   won    pnl   equity
# 176 -0.000345    0.0   0.0  True  3.450  483.525
# 177 -0.000537    0.0   0.0  True  5.375  488.900
# 178 -0.000657    0.0   0.0  True  6.575  495.475
# 179  0.000120    1.0   1.0  True  1.200  496.675
# 180  0.000355    1.0   1.0  True  3.550  500.225
# Net Profit            : $500.22
# Number Winning Trades : 140
# Number Losing Trades  : 41
# Percent Profitable    : 77.35%
# Avg Win Trade         : $4.584
# Avg Loss Trade         : $-3.452
# Largest Win Trade     : $30.025
# Largest Loss Trade     : $-13.875
# Profit Factor         : 4.53
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (907, 60)
# (907,)
# % of Class0 : 0.524807
# % of Class1 : 0.475193
# Training Accuracy: 0.719780
# Testing Accuracy: 0.729282
#        return  label  pred    won    pnl   equity
# 176 -0.000347    0.0   0.0   True  3.475  450.775
# 177 -0.000548    0.0   0.0   True  5.475  456.250
# 178 -0.000672    0.0   1.0  False -6.725  449.525
# 179  0.000120    1.0   0.0  False -1.200  448.325
# 180  0.000367    1.0   1.0   True  3.675  452.000
# Net Profit            : $452.00
# Number Winning Trades : 131
# Number Losing Trades  : 50
# Percent Profitable    : 72.38%
# Avg Win Trade         : $4.806
# Avg Loss Trade         : $-3.552
# Largest Win Trade     : $29.875
# Largest Loss Trade     : $-17.325
# Profit Factor         : 3.55
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.519252
# % of Class1 : 0.480748
# Training Accuracy: 0.780220
# Testing Accuracy: 0.718232
#        return  label  pred    won    pnl  equity
# 176 -0.000347    0.0   1.0  False -3.475  471.70
# 177 -0.000535    0.0   1.0  False -5.350  466.35
# 178 -0.000655    0.0   0.0   True  6.550  472.90
# 179  0.000115    1.0   0.0  False -1.150  471.75
# 180  0.000360    1.0   1.0   True  3.600  475.35
# Net Profit            : $475.35
# Number Winning Trades : 141
# Number Losing Trades  : 40
# Percent Profitable    : 77.90%
# Avg Win Trade         : $4.496
# Avg Loss Trade         : $-3.966
# Largest Win Trade     : $30.075
# Largest Loss Trade     : $-15.600
# Profit Factor         : 4.00
# (140, 60)
# (140,)
# % of Class0 : 0.500000
# % of Class1 : 0.500000
# Training Accuracy: 0.785714
# Testing Accuracy: 0.750000
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#       return  label  pred    won    pnl  equity
# 22 -0.000642    0.0   0.0   True  6.425  61.375
# 23  0.000062    1.0   0.0  False -0.625  60.750
# 24  0.000090    1.0   1.0   True  0.900  61.650
# 25  0.000280    1.0   0.0  False -2.800  58.850
# 26 -0.000270    0.0   0.0   True  2.700  61.550
# Net Profit            : $61.55
# Number Winning Trades : 21
# Number Losing Trades  : 6
# Percent Profitable    : 77.78%
# Avg Win Trade         : $3.593
# Avg Loss Trade         : $-2.317
# Largest Win Trade     : $10.250
# Largest Loss Trade     : $-4.500
# Profit Factor         : 5.43
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (1185, 60)
# (1185,)
# % of Class0 : 0.545992
# % of Class1 : 0.454008
# Training Accuracy: 0.810127
# Testing Accuracy: 0.729958
#      return  label  pred    won  pnl  equity
# 231  0.0000    0.0   1.0  False -0.0  448.75
# 232  0.0001    1.0   1.0   True  1.0  449.75
# 233  0.0000    0.0   0.0   True  0.0  449.75
# 234 -0.0001    0.0   0.0   True  1.0  450.75
# 235  0.0001    1.0   1.0   True  1.0  451.75
# Net Profit            : $451.75
# Number Winning Trades : 172
# Number Losing Trades  : 42
# Percent Profitable    : 80.37%
# Avg Win Trade         : $3.448
# Avg Loss Trade         : $-3.363
# Largest Win Trade     : $19.500
# Largest Loss Trade     : $-17.250
# Profit Factor         : 4.20
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.524752
# % of Class1 : 0.475248
# Training Accuracy: 0.769231
# Testing Accuracy: 0.734807
#       return  label  pred    won     pnl   equity
# 176 -0.02100    0.0   1.0  False  -210.0  65540.0
# 177 -0.02450    0.0   0.0   True   245.0  65785.0
# 178 -0.14600    0.0   0.0   True  1460.0  67245.0
# 179 -0.06925    0.0   0.0   True   692.5  67937.5
# 180  0.07300    1.0   0.0  False  -730.0  67207.5
# Net Profit            : $67207.50
# Number Winning Trades : 139
# Number Losing Trades  : 42
# Percent Profitable    : 76.80%
# Avg Win Trade         : $574.335
# Avg Loss Trade         : $-300.595
# Largest Win Trade     : $6312.500
# Largest Loss Trade     : $-1387.500
# Profit Factor         : 6.32
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.523652
# % of Class1 : 0.476348
# Training Accuracy: 0.796703
# Testing Accuracy: 0.707182
#       return  label  pred    won     pnl   equity
# 176 -0.02025    0.0   1.0  False  -202.5  69030.0
# 177 -0.02400    0.0   0.0   True   240.0  69270.0
# 178 -0.14675    0.0   0.0   True  1467.5  70737.5
# 179 -0.06900    0.0   0.0   True   690.0  71427.5
# 180  0.07275    1.0   0.0  False  -727.5  70700.0
# Net Profit            : $70700.00
# Number Winning Trades : 143
# Number Losing Trades  : 37
# Percent Profitable    : 79.44%
# Avg Win Trade         : $570.769
# Avg Loss Trade         : $-295.135
# Largest Win Trade     : $6315.000
# Largest Loss Trade     : $-1377.500
# Profit Factor         : 7.47
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.524752
# % of Class1 : 0.475248
# Training Accuracy: 0.796703
# Testing Accuracy: 0.723757
#       return  label  pred    won     pnl   equity
# 176 -0.02050    0.0   1.0  False  -205.0  74070.0
# 177 -0.02425    0.0   0.0   True   242.5  74312.5
# 178 -0.14600    0.0   0.0   True  1460.0  75772.5
# 179 -0.06875    0.0   0.0   True   687.5  76460.0
# 180  0.07300    1.0   0.0  False  -730.0  75730.0
# Net Profit            : $75730.00
# Number Winning Trades : 145
# Number Losing Trades  : 36
# Percent Profitable    : 80.11%
# Avg Win Trade         : $579.724
# Avg Loss Trade         : $-231.389
# Largest Win Trade     : $6317.500
# Largest Loss Trade     : $-780.000
# Profit Factor         : 10.09
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (907, 60)
# (907,)
# % of Class0 : 0.524807
# % of Class1 : 0.475193
# Training Accuracy: 0.791209
# Testing Accuracy: 0.707182
#       return  label  pred    won     pnl   equity
# 176 -0.02050    0.0   1.0  False  -205.0  70387.5
# 177 -0.02425    0.0   0.0   True   242.5  70630.0
# 178 -0.14675    0.0   0.0   True  1467.5  72097.5
# 179 -0.06950    0.0   0.0   True   695.0  72792.5
# 180  0.07350    1.0   0.0  False  -735.0  72057.5
# Net Profit            : $72057.50
# Number Winning Trades : 143
# Number Losing Trades  : 38
# Percent Profitable    : 79.01%
# Avg Win Trade         : $575.332
# Avg Loss Trade         : $-268.816
# Largest Win Trade     : $6307.500
# Largest Loss Trade     : $-795.000
# Profit Factor         : 8.05
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.528053
# % of Class1 : 0.471947
# Training Accuracy: 0.813187
# Testing Accuracy: 0.734807
#       return  label  pred    won     pnl   equity
# 176 -0.01950    0.0   1.0  False  -195.0  71952.5
# 177 -0.02275    0.0   0.0   True   227.5  72180.0
# 178 -0.14700    0.0   0.0   True  1470.0  73650.0
# 179 -0.07000    0.0   0.0   True   700.0  74350.0
# 180  0.07300    1.0   0.0  False  -730.0  73620.0
# Net Profit            : $73620.00
# Number Winning Trades : 147
# Number Losing Trades  : 34
# Percent Profitable    : 81.22%
# Avg Win Trade         : $565.357
# Avg Loss Trade         : $-279.044
# Largest Win Trade     : $6322.500
# Largest Loss Trade     : $-800.000
# Profit Factor         : 8.76
# (140, 60)
# (140,)
# % of Class0 : 0.578571
# % of Class1 : 0.421429
# Training Accuracy: 0.821429
# Testing Accuracy: 0.642857
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#      return  label  pred    won    pnl  equity
# 22 -0.03750    0.0   1.0  False -375.0  2747.5
# 23  0.00450    1.0   1.0   True   45.0  2792.5
# 24 -0.00150    0.0   0.0   True   15.0  2807.5
# 25 -0.00275    0.0   0.0   True   27.5  2835.0
# 26  0.00600    1.0   1.0   True   60.0  2895.0
# Net Profit            : $2895.00
# Number Winning Trades : 22
# Number Losing Trades  : 5
# Percent Profitable    : 81.48%
# Avg Win Trade         : $199.545
# Avg Loss Trade         : $-299.000
# Largest Win Trade     : $917.500
# Largest Loss Trade     : $-542.500
# Profit Factor         : 2.94
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (969, 60)
# (969,)
# % of Class0 : 0.524252
# % of Class1 : 0.475748
# Training Accuracy: 0.788660
# Testing Accuracy: 0.746114
#        return  label  pred    won    pnl    equity
# 188  0.008000    1.0   1.0   True  80.00  52022.50
# 189  0.004125    1.0   1.0   True  41.25  52063.75
# 190 -0.007250    0.0   1.0  False -72.50  51991.25
# 191  0.000375    1.0   1.0   True   3.75  51995.00
# 192  0.004625    1.0   1.0   True  46.25  52041.25
# Net Profit            : $52041.25
# Number Winning Trades : 152
# Number Losing Trades  : 41
# Percent Profitable    : 78.76%
# Avg Win Trade         : $410.107
# Avg Loss Trade         : $-251.098
# Largest Win Trade     : $2638.750
# Largest Loss Trade     : $-935.000
# Profit Factor         : 6.06
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.509351
# % of Class1 : 0.490649
# Training Accuracy: 0.758242
# Testing Accuracy: 0.734807
#        return  label  pred   won     pnl   equity
# 176  0.000405    1.0   1.0  True   4.050  476.400
# 177 -0.000107    0.0   0.0  True   1.075  477.475
# 178 -0.001035    0.0   0.0  True  10.350  487.825
# 179 -0.000722    0.0   0.0  True   7.225  495.050
# 180 -0.000033    0.0   0.0  True   0.325  495.375
# Net Profit            : $495.38
# Number Winning Trades : 137
# Number Losing Trades  : 44
# Percent Profitable    : 75.69%
# Avg Win Trade         : $4.630
# Avg Loss Trade         : $-3.157
# Largest Win Trade     : $29.950
# Largest Loss Trade     : $-9.450
# Profit Factor         : 4.57
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.512651
# % of Class1 : 0.487349
# Training Accuracy: 0.769231
# Testing Accuracy: 0.745856
#        return  label  pred   won     pnl   equity
# 176  0.000415    1.0   1.0  True   4.150  439.275
# 177 -0.000100    0.0   0.0  True   1.000  440.275
# 178 -0.001047    0.0   0.0  True  10.475  450.750
# 179 -0.000695    0.0   0.0  True   6.950  457.700
# 180 -0.000063    0.0   0.0  True   0.625  458.325
# Net Profit            : $458.32
# Number Winning Trades : 139
# Number Losing Trades  : 42
# Percent Profitable    : 76.80%
# Avg Win Trade         : $4.393
# Avg Loss Trade         : $-3.627
# Largest Win Trade     : $26.725
# Largest Loss Trade     : $-29.825
# Profit Factor         : 4.01
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (909, 60)
# (909,)
# % of Class0 : 0.512651
# % of Class1 : 0.487349
# Training Accuracy: 0.747253
# Testing Accuracy: 0.762431
#        return  label  pred   won     pnl   equity
# 176  0.000412    1.0   1.0  True   4.125  400.125
# 177 -0.000107    0.0   0.0  True   1.075  401.200
# 178 -0.001032    0.0   0.0  True  10.325  411.525
# 179 -0.000705    0.0   0.0  True   7.050  418.575
# 180 -0.000058    0.0   0.0  True   0.575  419.150
# Net Profit            : $419.15
# Number Winning Trades : 135
# Number Losing Trades  : 45
# Percent Profitable    : 75.00%
# Avg Win Trade         : $4.400
# Avg Loss Trade         : $-3.885
# Largest Win Trade     : $26.675
# Largest Loss Trade     : $-29.725
# Profit Factor         : 3.40
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (907, 60)
# (907,)
# % of Class0 : 0.517089
# % of Class1 : 0.482911
# Training Accuracy: 0.747253
# Testing Accuracy: 0.729282
#        return  label  pred   won     pnl   equity
# 176  0.000425    1.0   1.0  True   4.250  414.000
# 177 -0.000120    0.0   0.0  True   1.200  415.200
# 178 -0.001027    0.0   0.0  True  10.275  425.475
# 179 -0.000705    0.0   0.0  True   7.050  432.525
# 180 -0.000063    0.0   0.0  True   0.625  433.150
# Net Profit            : $433.15
# Number Winning Trades : 134
# Number Losing Trades  : 46
# Percent Profitable    : 74.44%
# Avg Win Trade         : $4.529
# Avg Loss Trade         : $-3.778
# Largest Win Trade     : $29.600
# Largest Loss Trade     : $-16.350
# Profit Factor         : 3.49
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# ...
# 178 -0.10225    0.0   0.0  True  1022.5  89807.5
# 179 -0.07450    0.0   0.0  True   745.0  90552.5
# 180  0.07475    1.0   1.0  True   747.5  91300.0
# /home/prashant/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# Net Profit            : $91300.00
# Number Winning Trades : 152
# Number Losing Trades  : 28
# Percent Profitable    : 84.44%
# Avg Win Trade         : $667.796
# Avg Loss Trade         : $-364.464
# Largest Win Trade     : $8302.500
# Largest Loss Trade     : $-1090.000
# Profit Factor         : 9.95
# (909, 60)
# (909,)
# % of Class0 : 0.488449
# % of Class1 : 0.511551
# Training Accuracy: 0.829670
# Testing Accuracy: 0.801105
#       return  label  pred   won     pnl   equity
# 176 -0.07425    0.0   0.0  True   742.5  87997.5
# 177 -0.02450    0.0   0.0  True   245.0  88242.5
# 178 -0.10250    0.0   0.0  True  1025.0  89267.5
# 179 -0.07475    0.0   0.0  True   747.5  90015.0
# 180  0.07625    1.0   1.0  True   762.5  90777.5
# /home/prashant/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# Net Profit            : $90777.50
# Number Winning Trades : 150
# Number Losing Trades  : 31
# Percent Profitable    : 82.87%
# Avg Win Trade         : $677.917
# Avg Loss Trade         : $-351.935
# Largest Win Trade     : $8322.500
# Largest Loss Trade     : $-1137.500
# Profit Factor         : 9.32
# (907, 60)
# (907,)
# % of Class0 : 0.495039
# % of Class1 : 0.504961
# Training Accuracy: 0.807692
# Testing Accuracy: 0.828729
#       return  label  pred   won     pnl   equity
# 176 -0.07525    0.0   0.0  True   752.5  80317.5
# 177 -0.02450    0.0   0.0  True   245.0  80562.5
# 178 -0.10300    0.0   0.0  True  1030.0  81592.5
# 179 -0.07275    0.0   0.0  True   727.5  82320.0
# 180  0.07500    1.0   1.0  True   750.0  83070.0
# /home/prashant/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# Net Profit            : $83070.00
# Number Winning Trades : 146
# Number Losing Trades  : 35
# Percent Profitable    : 80.66%
# Avg Win Trade         : $673.853
# Avg Loss Trade         : $-437.500
# Largest Win Trade     : $8275.000
# Largest Loss Trade     : $-1760.000
# Profit Factor         : 6.42
# (909, 60)
# (909,)
# % of Class0 : 0.496150
# % of Class1 : 0.503850
# Training Accuracy: 0.835165
# Testing Accuracy: 0.773481
#       return  label  pred   won     pnl   equity
# 176 -0.07450    0.0   0.0  True   745.0  83452.5
# 177 -0.02450    0.0   0.0  True   245.0  83697.5
# 178 -0.10200    0.0   0.0  True  1020.0  84717.5
# 179 -0.07475    0.0   0.0  True   747.5  85465.0
# 180  0.07475    1.0   1.0  True   747.5  86212.5
# /home/prashant/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Net Profit            : $86212.50
# Number Winning Trades : 151
# Number Losing Trades  : 30
# Percent Profitable    : 83.43%
# Avg Win Trade         : $655.795
# Avg Loss Trade         : $-427.083
# Largest Win Trade     : $8370.000
# Largest Loss Trade     : $-2547.500
# Profit Factor         : 7.73
# (140, 60)
# (140,)
# % of Class0 : 0.585714
# % of Class1 : 0.414286
# Training Accuracy: 0.714286
# Testing Accuracy: 0.714286
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#      return  label  pred   won    pnl  equity
# 22 -0.01925    0.0   0.0  True  192.5  4575.0
# 23 -0.01575    0.0   0.0  True  157.5  4732.5
# 24 -0.00775    0.0   0.0  True   77.5  4810.0
# 25 -0.00275    0.0   0.0  True   27.5  4837.5
# 26  0.02550    1.0   1.0  True  255.0  5092.5
# Net Profit            : $5092.50
# Number Winning Trades : 19
# Number Losing Trades  : 8
# Percent Profitable    : 70.37%
# Avg Win Trade         : $420.395
# Avg Loss Trade         : $-361.875
# Largest Win Trade     : $1015.000
# Largest Loss Trade     : $-675.000
# Profit Factor         : 2.76
# /home/prashant/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/prashant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/prashant/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# (969, 60)
# (969,)
# % of Class0 : 0.498452
# % of Class1 : 0.501548
# Training Accuracy: 0.824742
# Testing Accuracy: 0.746114
#        return  label  pred    won     pnl    equity
# 188 -0.008125    0.0   0.0   True   81.25  68871.25
# 189  0.008750    1.0   1.0   True   87.50  68958.75
# 190  0.018375    1.0   0.0  False -183.75  68775.00
# 191  0.009000    1.0   1.0   True   90.00  68865.00
# 192  0.008500    1.0   1.0   True   85.00  68950.00
# /home/prashant/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Net Profit            : $68950.00
# Number Winning Trades : 159
# Number Losing Trades  : 34
# Percent Profitable    : 82.38%
# Avg Win Trade         : $515.920
# Avg Loss Trade         : $-384.743
# Largest Win Trade     : $2561.250
# Largest Loss Trade     : $-1111.250
# Profit Factor         : 6.27
